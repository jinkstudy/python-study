# %% [markdown]
# #### 쉘모드 변경
#
# - Code 쉘 모드 : 파이썬 코드 실행
#
# - Markdown 쉘 모드 : 문서만들기
#
# ---
#
# * Code 쉘 : esc > y
# * Markdown 쉘 :exc > m

# %% [markdown]
# ### 서울 지하철 평균 이용객 수 분석
#
# ##### 가장 이용객 수가 많은 지하철은?
#
# + 강남
# + 홍대
#     + 서울
#     + 합정
#
# * 별표 하나는 번호 없는 목록 *
#
#
# *별표로 감싸면 기울이기(별표와 띄어쓰기 없이)*
#
# **별표 2개로 감싸면 굵게**
#
# ***별표 3개로 감싸면 기울이기 + 굵게***
#
#
# 가로선 --- 이면
#
# ---
#
# 인용문으로 >
#
# > code script

# %% [markdown]
# <div align="center"><font color='red'> 헬로우 월드</font> !!!</div>
#
# <img src = './dataset/puppy.jpg'>

# %% [markdown]
# [링크걸기](https://datascienceschool.net/view-notebook/39569f0132044097a15943bd8f440ca5/)
# 이미지 링크 [![텍스트](https://playdata.io/wp-content/uploads/2019/08/playdata_signature_w300h65.png)

# %% [markdown]
# ## <font color = 'green'> 코드결과</font>

# %%
import pandas
p1 = pandas.read_csv('./dataset/subway_data1.csv',encoding='utf-8')

# %%
p1
# Out:
#     구 분      역명          총계      일평균
# 0   1호선     서울역  11,933,924  132,599
# 1   1호선     시청역   4,221,693   46,908
# 2   1호선     종각역   8,441,749   93,797
# 3   1호선   종로3가역   6,725,558   74,728
# 4   1호선   종로5가역   5,038,305   55,981
# 5   1호선    동대문역   3,116,104   34,623
# 6   1호선    신설동역   2,992,487   33,250
# 7   1호선    제기동역   3,757,112   41,746
# 8   1호선    청량리역   5,555,303   61,726
# 9   1호선    동묘앞역   1,827,379   20,304
# 10  2호선     시청역   4,393,136   48,813
# 11  2호선   을지입구역   9,405,942  104,510
# 12  2호선   을지3가역   3,477,494   38,639
# 13  2호선   을지4가역   2,352,311   26,137
# 14  2호선     신당역   2,765,117   30,724
# 15  2호선   상왕십리역   1,814,646   20,163
# 16  2호선    왕십리역   3,398,257   37,758
# 17  2호선    한양대역   2,056,895   22,854
# 18  2호선     뚝섬역   2,833,608   31,485
# 19  2호선     성수역   4,573,215   50,814
# 20  2호선   건대입구역   8,560,101   95,112
# 21  2호선     구의역   4,296,198   47,736
# 22  2호선     강변역   9,248,361  102,760
# 23  2호선   잠실나루역   3,219,975   35,778
# ...

# %% [markdown]
# + *맨 좌측의 숫자는 index이다* <br/>
# + **인덱스는 자동으로 설정되지만 사용자가 설정도 가능합니다.**<br/>
# + ***value는 data를 의미한다***
#
#
# <table border='1'>
#     <tr><td>인덱스</td><td>값</td></tr>
#     <tr><td>1</td><td>데이터</td></tr>
#     <tr><td>2</td><td>데이터2</td></tr>

# %% [markdown]
# <a href ="https://playdata.io/"> <img src='dataset/map_subway.jpg'></a>
#
# 이미지를 클릭하면 지하철 홈페이지 링크 걸기
